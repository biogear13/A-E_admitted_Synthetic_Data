# %% [markdown]
# # Intro

# %% [markdown]
# The A&E Synthetic Data.csv is a large dataset; around 4.29GB in size. With this I would only analyze a fraction of the data.

# %% [markdown]
# # Download the DataBase

# %% [markdown]
# The raw data could be downloaded in the following link: https://nhsengland-direct-uploads.s3-eu-west-1.amazonaws.com/A%26E+Synthetic+Data.7z?versionId=null

# %% [markdown]
# Unzip the file to get the csv. Since the CSV is 4.2GB, I will not be including the file in this repository.

# %% [markdown]
# After I downloaded the dataset, I initially used pandas to read the csv but my computer's memory is not up for the task. I searched for an alternative method and I had found the `dask` package to be able to read all the data into a data frame.

# %%
# This is the code to install the dask package
# pip install dask

# %% [markdown]
# # Importing necessary packages

# %%
# import packages
from dask import dataframe as dd
import pandas as pd
import numpy as np

# %% [markdown]
# # Read the CSV

# %% [markdown]
# The dask dataframe was having trouble in automatically detecting the data types of the different columns of the dataset. So I opened the file in excel just to see the column names and get a feel of the data. I then specified the datypes for each row in the following `read_csv` code.

# %%
a_and_e_synth_df = dd.read_csv('A&E Synthetic Data.csv', skiprows=1, dtype={\
    'IMD_Decile_From_LSOA':'object',
    'Age_Band':'object',
    'Sex':'object',
    'AE_Arrive_Date':'object',
    'AE_Arrive_HourOfDay':'object',
    'AE_Time_Mins':'float64',
    'AE_HRG':'object',
    'AE_Num_Diagnoses':'int64',
    'AE_Num_Investigations':'int64',
    'AE_Num_Treatments':'int64',
    'AE_Arrival_Mode':'object',
    'Provider_Patient_Distance_Miles':'float64',
    'ProvID':'object',
    'Admitted_Flag':'object',
    'Admission_Method':'object',
    'ICD10_Chapter_Code':'object',
    'Treatment_Function_Code':'object',
    'Length_Of_Stay_Days':'float64'})
a_and_e_synth_df.head(10)
# Out:
#   IMD_Decile_From_LSOA Age_Band Sex       AE_Arrive_Date AE_Arrive_HourOfDay  \
# 0                    2    65-84   1  2015-07-02 00:00:00               17-20
# 1                    6    18-24   1  2017-05-31 00:00:00               17-20
# 2                    2    65-84   2  2015-10-25 00:00:00               13-16
# 3                    4    25-44   1  2014-06-16 00:00:00               21-24
# 4                    7    18-24   2  2017-11-18 00:00:00               13-16
# 5                    4      85+   2  2015-09-30 00:00:00               13-16
# 6                    8    65-84   2  2015-02-04 00:00:00               09-12
# 7                    2    45-64   2  2015-01-11 00:00:00               09-12
# 8                    7     1-17   2  2016-11-17 00:00:00               09-12
# 9                    3    65-84   2  2018-01-12 00:00:00               17-20
#
#    AE_Time_Mins   AE_HRG  AE_Num_Diagnoses  AE_Num_Investigations  \
# 0         210.0     High                 1                      5
# 1          20.0      Low                 0                      1
# 2         280.0  Nothing                 1                      0
# 3         150.0      Low                 1                      2
# 4         180.0      Low                 1                      1
# 5         240.0      Low                 1                     10
# 6         160.0  Nothing                 0                      1
# 7         210.0      Low                 2                      2
# 8          30.0  Nothing                 1                      1
# 9         100.0      Low                 1                      1
#
#    AE_Num_Treatments AE_Arrival_Mode  Provider_Patient_Distance_Miles ProvID  \
# 0                  3               2                              1.0  15207
# 1                  1               2                              5.0  15321
# 2                  1               1                              2.0  15269
# 3                  2               2                              1.0  15239
# 4                  2               2                              1.0  15286
# 5                 10               1                              2.0  15310
# 6                  1               1                              2.0  15260
# 7                  1               2                             13.0  15312
# 8                  1               2                              9.0  15396
# 9                  1               2                              0.0  15383
#
#   Admitted_Flag Admission_Method ICD10_Chapter_Code Treatment_Function_Code  \
# 0             1               21              XVIII                     180
# 1             0              NaN                NaN                     NaN
# 2             0              NaN                NaN                     NaN
# 3             0              NaN                NaN                     NaN
# 4             0              NaN                NaN                     NaN
# 5             1               21                 IX                   OTHER
# 6             1               21              XVIII                     300
# 7             0              NaN                NaN                     NaN
# 8             0              NaN                NaN                     NaN
# 9             0              NaN                NaN                     NaN
#
#    Length_Of_Stay_Days
# 0                  1.0
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                 16.0
# 6                  1.0
# 7                  NaN
# 8                  NaN
# 9                  NaN

# %% [markdown]
# # Assess the data

# %% [markdown]
# First I will look at the different columns

# %%
# get the names of each column
columns=a_and_e_synth_df.columns
columns
# Out:
# Index(['IMD_Decile_From_LSOA', 'Age_Band', 'Sex', 'AE_Arrive_Date',
#        'AE_Arrive_HourOfDay', 'AE_Time_Mins', 'AE_HRG', 'AE_Num_Diagnoses',
#        'AE_Num_Investigations', 'AE_Num_Treatments', 'AE_Arrival_Mode',
#        'Provider_Patient_Distance_Miles', 'ProvID', 'Admitted_Flag',
#        'Admission_Method', 'ICD10_Chapter_Code', 'Treatment_Function_Code',
#        'Length_Of_Stay_Days'],
#       dtype='object')

# %%
# iterate for each column and get the description
#for column in columns:
#    print(a_and_e_synth_df[column].describe().compute())

# %% [markdown]
# There are 65,836,575 rows in the data set and  it took 11 min to check the description of each of the columns. For this analysis, I will look into the data of all admitted persons.

# %% [markdown]
# # Get all admitted patients

# %%
# Get all admitted patients
admitted = a_and_e_synth_df[a_and_e_synth_df['Admitted_Flag']=='1']

# %%
# Check how many rows available
admitted['IMD_Decile_From_LSOA'].count().compute()
# Out:
# 13050415

# %% [markdown]
# There is still too much rows. With this I would concentrate on only one provider so I would use the provider that have highest number of entries.

# %% [markdown]
# # Get all the entries for the provider with the highest number of entries.

# %%
# Check which provider has the highest number of entries
admitted['ProvID'].describe().compute()
# Out:
# unique         238
# count     13113928
# top          15098
# freq        326444
# Name: ProvID, dtype: object

# %%
# Get all the entries of the provider that has the highest number entries
provider=admitted[admitted['ProvID']=='15098'].compute()
provider
# Out:
#        IMD_Decile_From_LSOA Age_Band Sex       AE_Arrive_Date  \
# 284                       2     1-17   2  2015-05-21 00:00:00
# 1710                      2    65-84   1  2017-09-30 00:00:00
# 1852                      3     1-17   2  2016-09-21 00:00:00
# 1855                      1      85+   1  2014-03-23 00:00:00
# 1909                      2     1-17   2  2017-11-11 00:00:00
# ...                     ...      ...  ..                  ...
# 738718                    1     1-17   1  2017-11-30 00:00:00
# 738790                    3    65-84   1  2017-05-12 00:00:00
# 738989                    3    25-44   2  2015-07-12 00:00:00
# 739406                    2    45-64   1  2016-08-26 00:00:00
# 739560                    2    65-84   1  2017-08-18 00:00:00
#
#        AE_Arrive_HourOfDay  AE_Time_Mins   AE_HRG  AE_Num_Diagnoses  \
# 284                  17-20         290.0  Nothing                 0
# 1710                 13-16          90.0      Low                 1
# 1852                 17-20         240.0      Low                 0
# 1855                 05-08         240.0      Low                 3
# 1909                 13-16         130.0      Low                 0
# ...                    ...           ...      ...               ...
# 738718               21-24         180.0   Medium                 0
# 738790               21-24         240.0   Medium                 3
# 738989               01-04         190.0   Medium                 1
# 739406               17-20         220.0   Medium                 0
# 739560               13-16         240.0      Low                 0
#
#         AE_Num_Investigations  AE_Num_Treatments AE_Arrival_Mode  \
# 284                         1                  2               2
# 1710                        1                  1               2
# 1852                        1                  1               2
# 1855                        8                  3               1
# 1909                       10                  3               2
# ...                       ...                ...             ...
# 738718                      8                  6               2
# 738790                      6                  7               2
# 738989                      5                  3               1
# 739406                     10                  4               1
# 739560                      7                  3               1
#
#         Provider_Patient_Distance_Miles ProvID Admitted_Flag Admission_Method  \
# 284                                 4.0  15098             1               28
# 1710                                5.0  15098             1               21
# 1852                                1.0  15098             1               21
# 1855                                2.0  15098             1               21
# 1909                                4.0  15098             1               21
# ...                                 ...    ...           ...              ...
# 738718                              2.0  15098             1               21
# 738790                              4.0  15098             1               21
# 738989                              1.0  15098             1               21
# 739406                            168.0  15098             1               21
# 739560                              0.0  15098             1               21
#
#        ICD10_Chapter_Code Treatment_Function_Code  Length_Of_Stay_Days
# 284                   XIV                     420                  1.0
# 1710                   XI                     100                  0.0
# 1852                    X                     420                  0.0
# 1855                   XI                     300                  0.0
# 1909                XVIII                     180                  1.0
# ...                   ...                     ...                  ...
# 738718              Other                     420                  0.0
# 738790              Other                     300                  3.0
# 738989              Other                   OTHER                  1.0
# 739406              XVIII                   OTHER                 43.0
# 739560                XIX                   OTHER                  1.0
#
# [326444 rows x 18 columns]

# %%
provider.drop(columns=['Admitted_Flag','ProvID'], inplace=True)
provider
# Out:
#        IMD_Decile_From_LSOA Age_Band Sex       AE_Arrive_Date  \
# 284                       2     1-17   2  2015-05-21 00:00:00
# 1710                      2    65-84   1  2017-09-30 00:00:00
# 1852                      3     1-17   2  2016-09-21 00:00:00
# 1855                      1      85+   1  2014-03-23 00:00:00
# 1909                      2     1-17   2  2017-11-11 00:00:00
# ...                     ...      ...  ..                  ...
# 738718                    1     1-17   1  2017-11-30 00:00:00
# 738790                    3    65-84   1  2017-05-12 00:00:00
# 738989                    3    25-44   2  2015-07-12 00:00:00
# 739406                    2    45-64   1  2016-08-26 00:00:00
# 739560                    2    65-84   1  2017-08-18 00:00:00
#
#        AE_Arrive_HourOfDay  AE_Time_Mins   AE_HRG  AE_Num_Diagnoses  \
# 284                  17-20         290.0  Nothing                 0
# 1710                 13-16          90.0      Low                 1
# 1852                 17-20         240.0      Low                 0
# 1855                 05-08         240.0      Low                 3
# 1909                 13-16         130.0      Low                 0
# ...                    ...           ...      ...               ...
# 738718               21-24         180.0   Medium                 0
# 738790               21-24         240.0   Medium                 3
# 738989               01-04         190.0   Medium                 1
# 739406               17-20         220.0   Medium                 0
# 739560               13-16         240.0      Low                 0
#
#         AE_Num_Investigations  AE_Num_Treatments AE_Arrival_Mode  \
# 284                         1                  2               2
# 1710                        1                  1               2
# 1852                        1                  1               2
# 1855                        8                  3               1
# 1909                       10                  3               2
# ...                       ...                ...             ...
# 738718                      8                  6               2
# 738790                      6                  7               2
# 738989                      5                  3               1
# 739406                     10                  4               1
# 739560                      7                  3               1
#
#         Provider_Patient_Distance_Miles Admission_Method ICD10_Chapter_Code  \
# 284                                 4.0               28                XIV
# 1710                                5.0               21                 XI
# 1852                                1.0               21                  X
# 1855                                2.0               21                 XI
# 1909                                4.0               21              XVIII
# ...                                 ...              ...                ...
# 738718                              2.0               21              Other
# 738790                              4.0               21              Other
# 738989                              1.0               21              Other
# 739406                            168.0               21              XVIII
# 739560                              0.0               21                XIX
#
#        Treatment_Function_Code  Length_Of_Stay_Days
# 284                        420                  1.0
# 1710                       100                  0.0
# 1852                       420                  0.0
# 1855                       300                  0.0
# 1909                       180                  1.0
# ...                        ...                  ...
# 738718                     420                  0.0
# 738790                     300                  3.0
# 738989                   OTHER                  1.0
# 739406                   OTHER                 43.0
# 739560                   OTHER                  1.0
#
# [326444 rows x 16 columns]

# %%
# Save the dataframe to a csv file
provider.to_csv('AnE_Synthetic_Data_Provider_Admission.csv', index=False)
